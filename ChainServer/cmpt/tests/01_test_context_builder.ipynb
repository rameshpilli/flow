# %% [markdown]
# # Stage 1: Context Builder - Interactive Tests
#
# This notebook tests the **Context Builder** service which calls real Foundation Service APIs.
#
# **APIs Used:**
# - `/query_resolution` - Resolves company name → ticker, industry
# - `/company_earnings_calendar` - Gets earnings dates using ticker
#
# **What it tests:**
# - Company info extraction via Foundation Service
# - Temporal context extraction (earnings dates)
# - Persona extraction (RBC & client)
# - User overrides
# - Error handling & fallbacks

# %%
# Setup path and imports
import sys
sys.path.insert(0, "../..")

# Load environment variables
from pathlib import Path
from dotenv import load_dotenv
env_path = Path("../.env")
if env_path.exists():
    load_dotenv(env_path)
    print(f"✓ Loaded .env from {env_path}")

from cmpt.services import ContextBuilderService, ChainRequest, ChainRequestOverrides
from cmpt.services.models import ContextBuilderOutput

print("✓ Imports successful")

# %% [markdown]
# ## Check Foundation Service URLs

# %%
import os

# Check configured URLs
base_url = os.getenv("FOUNDATION_BASE_URL", "https://tg40-aiden-foundation-service.cfk.devfg.rbc.com")
query_url = os.getenv("FOUNDATION_QUERY_RESOLUTION_URL", f"{base_url}/query_resolution")
earnings_url = os.getenv("FOUNDATION_EARNING_CALENDAR_URL", f"{base_url}/company_earnings_calendar")

print("Foundation Service Configuration:")
print(f"  Base URL: {base_url}")
print(f"  Query Resolution: {query_url}")
print(f"  Earnings Calendar: {earnings_url}")

# %% [markdown]
# ## Test 1: Basic Company Resolution
#
# Test the `/query_resolution` API to resolve a company name to ticker and industry.

# %%
async def test_company_resolution():
    """Test company resolution via Foundation Service API."""
    service = ContextBuilderService()
    
    request = ChainRequest(
        corporate_company_name="Apple",  # Fuzzy name - API should resolve to "Apple, Inc."
        meeting_datetime="2025-01-15T10:00:00Z",
    )
    
    output = await service.execute(request)
    
    print("="*60)
    print("  Company Resolution Results")
    print("="*60)
    print(f"  Input: 'Apple'")
    print(f"  Resolved Company: {output.company_name}")
    print(f"  Ticker: {output.ticker}")
    print(f"  Industry: {output.company_info.industry if output.company_info else 'N/A'}")
    print()
    
    if output.errors:
        print("  ⚠️ Errors (API may not be reachable):")
        for k, v in output.errors.items():
            print(f"    {k}: {v}")
    else:
        print("  ✓ No errors")
    
    return output

output = await test_company_resolution()

# %% [markdown]
# ## Test 2: Earnings Calendar & Temporal Context
#
# Test the `/company_earnings_calendar` API to get earnings dates.

# %%
async def test_earnings_calendar():
    """Test earnings calendar extraction."""
    service = ContextBuilderService()
    
    request = ChainRequest(
        corporate_company_name="Microsoft",
        meeting_datetime="2025-03-15T14:00:00Z",  # Q1 meeting
    )
    
    output = await service.execute(request)
    
    print("="*60)
    print("  Earnings Calendar Results")
    print("="*60)
    print(f"  Company: {output.company_name}")
    print(f"  Ticker: {output.ticker}")
    print()
    
    if output.temporal_context:
        tc = output.temporal_context
        print("  Temporal Context:")
        print(f"    Meeting Date: {tc.meeting_date}")
        print(f"    Next Earnings: {tc.event_dt or 'N/A'}")
        print(f"    Days to Earnings: {tc.days_to_earnings if tc.days_to_earnings is not None else 'N/A'}")
        print(f"    Fiscal Period: Q{tc.fiscal_quarter} {tc.fiscal_year}")
        print(f"    News Lookback: {tc.news_lookback_days} days")
        print(f"    Filing Quarters: {tc.filing_quarters}")
    else:
        print("  ⚠️ No temporal context extracted")
    
    return output

output = await test_earnings_calendar()

# %% [markdown]
# ## Test 3: Try Different Companies
#
# Test the resolution for various company names.

# %%
async def test_multiple_companies():
    """Test company resolution for multiple companies."""
    service = ContextBuilderService()
    
    companies = [
        "Tesla",
        "Google",
        "Amazon",
        "Netflix",
        "JP Morgan",
    ]
    
    print("="*70)
    print("  Multi-Company Resolution Test")
    print("="*70)
    print(f"  {'Input':<15} {'Resolved Name':<25} {'Ticker':<10} {'Industry'}")
    print("-"*70)
    
    for company in companies:
        request = ChainRequest(
            corporate_company_name=company,
            meeting_datetime="2025-01-15T10:00:00Z",
        )
        output = await service.execute(request)
        
        resolved_name = output.company_name or "N/A"
        ticker = output.ticker or "N/A"
        industry = output.company_info.industry if output.company_info else "N/A"
        
        # Truncate for display
        resolved_name = resolved_name[:23] + ".." if len(resolved_name) > 25 else resolved_name
        industry = industry[:20] + ".." if industry and len(industry) > 22 else (industry or "N/A")
        
        print(f"  {company:<15} {resolved_name:<25} {ticker:<10} {industry}")
    
    print()

await test_multiple_companies()

# %% [markdown]
# ## Test 4: RBC Persona Extraction

# %%
async def test_rbc_persona():
    """Test RBC employee persona extraction."""
    service = ContextBuilderService()
    
    request = ChainRequest(
        corporate_company_name="Tesla",
        meeting_datetime="2025-02-20T10:00:00Z",
        rbc_employee_email="john.smith@rbc.com",
    )
    
    output = await service.execute(request)
    
    print("="*60)
    print("  RBC Persona Extraction")
    print("="*60)
    
    if output.rbc_persona:
        p = output.rbc_persona
        print(f"  Name: {p.name}")
        print(f"  First Name: {p.first_name}")
        print(f"  Last Name: {p.last_name}")
        print(f"  Email: {p.email}")
        print(f"  Is Internal: {p.is_internal}")
        print(f"  Source: {p.source}")
        print("\n  ✓ RBC persona extracted successfully")
    else:
        print("  ⚠️ No RBC persona extracted")
    
    return output

output = await test_rbc_persona()

# %% [markdown]
# ## Test 5: Client Persona Extraction

# %%
async def test_client_persona():
    """Test corporate client persona extraction."""
    service = ContextBuilderService()
    
    request = ChainRequest(
        corporate_company_name="Amazon",
        meeting_datetime="2025-02-20T10:00:00Z",
        corporate_client_email="jane.doe@amazon.com",
    )
    
    output = await service.execute(request)
    
    print("="*60)
    print("  Client Persona Extraction")
    print("="*60)
    
    if output.corporate_client_personas:
        for i, client in enumerate(output.corporate_client_personas):
            print(f"\n  Client {i+1}:")
            print(f"    Name: {client.name}")
            print(f"    Email: {client.email}")
            print(f"    Company: {client.company}")
            print(f"    Is Internal: {client.is_internal}")
            print(f"    Source: {client.source}")
        print("\n  ✓ Client personas extracted successfully")
    else:
        print("  ⚠️ No client personas extracted")
    
    return output

output = await test_client_persona()

# %% [markdown]
# ## Test 6: Multiple Client Names

# %%
async def test_multiple_clients():
    """Test extraction of multiple client personas from comma-separated names."""
    service = ContextBuilderService()
    
    request = ChainRequest(
        corporate_company_name="Google",
        meeting_datetime="2025-02-20T10:00:00Z",
        corporate_client_names="Sundar Pichai, Ruth Porat, Philipp Schindler",
    )
    
    output = await service.execute(request)
    
    print("="*60)
    print("  Multiple Client Personas")
    print("="*60)
    print(f"  Input: 'Sundar Pichai, Ruth Porat, Philipp Schindler'")
    print(f"  Extracted: {len(output.corporate_client_personas)} personas")
    print()
    
    for client in output.corporate_client_personas:
        print(f"    - {client.name} (First: {client.first_name}, Last: {client.last_name})")
    
    return output

output = await test_multiple_clients()

# %% [markdown]
# ## Test 7: User Overrides
#
# Test that user-provided overrides take precedence over API values.

# %%
async def test_user_overrides():
    """Test that user overrides take precedence."""
    service = ContextBuilderService()
    
    request = ChainRequest(
        corporate_company_name="Google",
        meeting_datetime="2025-04-15T10:00:00Z",
        overrides=ChainRequestOverrides(
            ticker="GOOGL",  # Override ticker
            fiscal_quarter="Q2",  # Override quarter
            fiscal_year="2025",  # Override year
            next_earnings_date="2025-04-25",  # Override earnings date
            news_lookback_days=60,  # Custom lookback
            filing_quarters=12,  # More quarters
        ),
    )
    
    output = await service.execute(request)
    
    print("="*60)
    print("  User Overrides Test")
    print("="*60)
    print("  Overrides provided:")
    print("    ticker='GOOGL', fiscal_quarter='Q2', fiscal_year='2025'")
    print("    next_earnings_date='2025-04-25', news_lookback_days=60")
    print()
    print("  Results:")
    print(f"    Ticker: {output.company_info.ticker}")
    print(f"    Fiscal Quarter: Q{output.temporal_context.fiscal_quarter}")
    print(f"    Fiscal Year: {output.temporal_context.fiscal_year}")
    print(f"    Next Earnings: {output.temporal_context.event_dt}")
    print(f"    News Lookback: {output.temporal_context.news_lookback_days} days")
    print(f"    Filing Quarters: {output.temporal_context.filing_quarters}")
    
    # Verify overrides were applied
    assert output.company_info.ticker == "GOOGL"
    assert output.temporal_context.fiscal_quarter == "2"
    assert output.temporal_context.news_lookback_days == 60
    print("\n  ✓ All overrides applied correctly")
    
    return output

output = await test_user_overrides()

# %% [markdown]
# ## Test 8: Skip API Calls (Offline Mode)

# %%
async def test_skip_api():
    """Test skipping API calls with overrides."""
    service = ContextBuilderService()
    
    request = ChainRequest(
        corporate_company_name="Unknown Corp",
        meeting_datetime="2025-06-15T10:00:00Z",
        overrides=ChainRequestOverrides(
            ticker="UNKN",
            industry="Technology",
            skip_earnings_calendar_api=True,  # Skip API call
        ),
    )
    
    output = await service.execute(request)
    
    print("="*60)
    print("  Skip API Test (Offline Mode)")
    print("="*60)
    print(f"  Company: {output.company_name}")
    print(f"  Ticker: {output.ticker}")
    print(f"  Industry: {output.company_info.industry if output.company_info else 'N/A'}")
    print()
    print("  Temporal Context (computed, not from API):")
    if output.temporal_context:
        print(f"    Meeting Date: {output.temporal_context.meeting_date}")
        print(f"    Fiscal Period: Q{output.temporal_context.fiscal_quarter} {output.temporal_context.fiscal_year}")
    print()
    print("  ✓ Works without API access")
    
    return output

output = await test_skip_api()

# %% [markdown]
# ## Test 9: Error Handling

# %%
async def test_error_handling():
    """Test graceful error handling with very short timeout."""
    service = ContextBuilderService(
        http_timeout=0.001,  # Very short timeout to force API failure
        extractor_timeouts={"firm_temporal": 0.001}
    )
    
    request = ChainRequest(
        corporate_company_name="TestCorp",
        meeting_datetime="2025-01-01T10:00:00Z",
    )
    
    # Should not raise, should capture errors and use fallbacks
    output = await service.execute(request)
    
    print("="*60)
    print("  Error Handling Test")
    print("="*60)
    print(f"  ✓ Output returned despite errors")
    print(f"  Company (fallback): {output.company_name}")
    print()
    
    if output.errors:
        print("  Captured Errors:")
        for k, v in output.errors.items():
            print(f"    {k}: {v[:50]}..." if len(v) > 50 else f"    {k}: {v}")
    
    print()
    print("  ✓ Graceful error handling works")
    
    return output

output = await test_error_handling()

# %% [markdown]
# ## Test 10: Timing Metrics

# %%
async def test_timing_metrics():
    """Test that timing metrics are captured."""
    service = ContextBuilderService()
    
    request = ChainRequest(
        corporate_company_name="Netflix",
        meeting_datetime="2025-01-20T10:00:00Z",
        rbc_employee_email="analyst@rbc.com",
        corporate_client_email="executive@netflix.com",
    )
    
    output = await service.execute(request)
    
    print("="*60)
    print("  Timing Metrics")
    print("="*60)
    
    if output.timing_ms:
        for key, value in output.timing_ms.items():
            bar = "█" * int(value / 100)  # Visual bar (1 block per 100ms)
            print(f"    {key:<20}: {value:>8.2f}ms {bar}")
    else:
        print("  ⚠️ No timing metrics captured")
    
    return output

output = await test_timing_metrics()

# %% [markdown]
# ## Test 11: Full Output Inspection

# %%
async def test_full_output():
    """Display full Context Builder output for inspection."""
    service = ContextBuilderService()
    
    request = ChainRequest(
        corporate_company_name="Apple Inc",
        meeting_datetime="2025-02-15T10:00:00Z",
        rbc_employee_email="analyst@rbc.com",
        corporate_client_email="tim.cook@apple.com",
    )
    
    output = await service.execute(request)
    
    print("="*70)
    print("  Full Context Builder Output")
    print("="*70)
    
    # Company Info
    print("\n  COMPANY INFO:")
    print(f"    Name: {output.company_name}")
    print(f"    Ticker: {output.ticker}")
    if output.company_info:
        print(f"    Industry: {output.company_info.industry}")
        print(f"    Sector: {output.company_info.sector}")
        print(f"    CIK: {output.company_info.cik}")
    
    # Temporal Context
    print("\n  TEMPORAL CONTEXT:")
    if output.temporal_context:
        tc = output.temporal_context
        print(f"    Meeting Date: {tc.meeting_date}")
        print(f"    Next Earnings: {tc.event_dt}")
        print(f"    Days to Earnings: {tc.days_to_earnings}")
        print(f"    Fiscal Period: Q{tc.fiscal_quarter} {tc.fiscal_year}")
        print(f"    News Lookback: {tc.news_lookback_days} days")
        print(f"    Filing Quarters: {tc.filing_quarters}")
    
    # RBC Persona
    print("\n  RBC PERSONA:")
    if output.rbc_persona:
        print(f"    Name: {output.rbc_persona.name}")
        print(f"    Email: {output.rbc_persona.email}")
        print(f"    Source: {output.rbc_persona.source}")
    else:
        print("    (none)")
    
    # Client Personas
    print("\n  CLIENT PERSONAS:")
    if output.corporate_client_personas:
        for c in output.corporate_client_personas:
            print(f"    - {c.name} ({c.email}) [{c.source}]")
    else:
        print("    (none)")
    
    # Errors
    print("\n  ERRORS:")
    if output.errors:
        for k, v in output.errors.items():
            print(f"    {k}: {v}")
    else:
        print("    (none)")
    
    # Timing
    print("\n  TIMING (ms):")
    if output.timing_ms:
        for k, v in output.timing_ms.items():
            print(f"    {k}: {v:.2f}")
    
    return output

output = await test_full_output()

# %% [markdown]
# ## Interactive: Test Your Own Company

# %%
# Change these values and run the cell!
COMPANY_NAME = "Nvidia"  # Try: "Tesla", "Amazon", "Goldman Sachs", "Pfizer"
MEETING_DATE = "2025-03-01T10:00:00Z"

async def interactive_test():
    service = ContextBuilderService()
    
    request = ChainRequest(
        corporate_company_name=COMPANY_NAME,
        meeting_datetime=MEETING_DATE,
    )
    
    output = await service.execute(request)
    
    print(f"\n{'='*60}")
    print(f"  Results for: {COMPANY_NAME}")
    print(f"{'='*60}")
    print(f"  Resolved Name: {output.company_name}")
    print(f"  Ticker: {output.ticker}")
    print(f"  Industry: {output.company_info.industry if output.company_info else 'N/A'}")
    
    if output.temporal_context:
        tc = output.temporal_context
        print(f"\n  Temporal Context:")
        print(f"    Next Earnings: {tc.event_dt or 'N/A'}")
        print(f"    Days to Earnings: {tc.days_to_earnings if tc.days_to_earnings is not None else 'N/A'}")
        print(f"    Fiscal Period: Q{tc.fiscal_quarter} {tc.fiscal_year}")
    
    if output.errors:
        print(f"\n  ⚠️ Errors: {list(output.errors.keys())}")
    
    return output

output = await interactive_test()

# %% [markdown]
# ## Summary

# %%
print("="*60)
print("  Stage 1: Context Builder - Test Summary")
print("="*60)
print()
print("  APIs Used:")
print("    • /query_resolution - Company name → ticker, industry")
print("    • /company_earnings_calendar - Ticker → earnings dates")
print()
print("  Tests Covered:")
print("    ✓ Company resolution (fuzzy name → structured data)")
print("    ✓ Earnings calendar extraction")
print("    ✓ Multi-company resolution")
print("    ✓ RBC persona extraction")
print("    ✓ Client persona extraction (email & names)")
print("    ✓ User overrides")
print("    ✓ Skip API mode (offline)")
print("    ✓ Error handling & fallbacks")
print("    ✓ Timing metrics")
print()
print("  Note: If APIs are not reachable (no VPN), fallback")
print("  values are used and errors are captured gracefully.")
